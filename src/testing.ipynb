# %%
bin_data = b'\x00\x00\x00\x00\x00\x00\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00'
text = bin_data.decode('ascii', errors='replace')
print(repr(text))
# Out:
# '\x00\x00\x00\x00\x00\x00\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00'
